# %% [markdown]
# # pandas intro
# 28/06/2022

# %% [markdown]
# After this encounter you should be able to
# - use selected methods of the pandas library
# - use pandas documentation for finding and using selected methods

# %% [markdown]
# ### Table of content
# 1. [import pandas](#import)
# 2. [read csv file](#read)
# 3. [index and columns](#index)
# 4. [head and tail](#head)
# 5. [set index](#setindex)
# 6. [loc and iloc](#loc)
# 7. [select conditional](#masking)
# 8. [nan](#nan)
# 9. [save files](#save)
# 10. [plot](#plot)

# %% [markdown]
# <a id='import' />

# %% [markdown]
# #### Import ```pandas``` package as ```pd```

# %%
import pandas as pd

# %% [markdown]
# [UP](#toc)
# <a id='read'/>

# %% [markdown]
# #### Load data file with separator ```,```

# %%
df = pd.read_csv('../../resources/population.csv', sep=',')
df
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    3323519.0  3448982.0  3625022.0  3810047.0  3973968.0  4169690.0
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3     438671.0   457234.0   478227.0   506889.0   552800.0   610036.0
# 4    2713079.0  2880355.0  3082721.0  3299305.0  3536468.0  3811028.0
# ..         ...        ...        ...        ...        ...        ...
# 270        NaN        NaN        NaN        NaN        NaN        NaN
# 271        NaN        NaN        NaN        NaN        NaN        NaN
# 272        NaN        NaN        NaN        NaN        NaN        NaN
# 273        NaN        NaN        NaN        NaN        NaN        NaN
# 274        NaN        NaN        NaN        NaN        NaN        NaN
#
#           1880  ...        2006        2007        2008        2009  \
# 0          NaN  ...         NaN         NaN         NaN         NaN
# 1    4419695.0  ...  25183615.0  25877544.0  26528741.0  27207291.0
# 2          NaN  ...     15700.0     15700.0     15700.0         NaN
# 3     672544.0  ...   3050741.0   3010849.0   2968026.0   2929886.0
# 4    4143163.0  ...  33749328.0  34261971.0  34811059.0  35401790.0
# ..         ...  ...         ...         ...         ...         ...
# 270        NaN  ...         NaN         NaN         NaN         NaN
# 271        NaN  ...         NaN         NaN         NaN         NaN
# 272        NaN  ...         NaN         NaN         NaN         NaN
# 273        NaN  ...         NaN         NaN         NaN         NaN
# 274        NaN  ...         NaN         NaN         NaN         NaN
#
#            2010        2011        2012        2013        2014        2015
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1    27962207.0  28809167.0  29726803.0  30682500.0  31627506.0  32526562.0
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3     2901883.0   2886010.0   2880667.0   2883281.0   2889676.0   2896679.0
# 4    36036159.0  36717132.0  37439427.0  38186135.0  38934334.0  39666519.0
# ..          ...         ...         ...         ...         ...         ...
# 270         NaN         NaN         NaN         NaN         NaN         NaN
# 271         NaN         NaN         NaN         NaN         NaN         NaN
# 272         NaN         NaN         NaN         NaN         NaN         NaN
# 273         NaN         NaN         NaN         NaN         NaN         NaN
# 274         NaN         NaN         NaN         NaN         NaN         NaN
#
# [275 rows x 82 columns]

# %% [markdown]
# [UP](#toc)
# <a id='index'/>

# %% [markdown]
# #### Get index and columns of the DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=275, step=1)

# %%
df.shape
# Out:
# (275, 82)

# %% [markdown]
# [UP](#toc)
# <a id='head'/>

# %% [markdown]
# #### Get first (```head```) or last (```tail```) 5 rows of DataFrame

# %%
df.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  25877544.0  26528741.0  27207291.0  27962207.0  28809167.0  29726803.0
# 2     15700.0     15700.0         NaN         NaN         NaN         NaN
# 3   3010849.0   2968026.0   2929886.0   2901883.0   2886010.0   2880667.0
# 4  34261971.0  34811059.0  35401790.0  36036159.0  36717132.0  37439427.0
#
#          2013        2014        2015
# 0         NaN         NaN         NaN
# 1  30682500.0  31627506.0  32526562.0
# 2         NaN         NaN         NaN
# 3   2883281.0   2889676.0   2896679.0
# 4  38186135.0  38934334.0  39666519.0
#
# [5 rows x 82 columns]

# %%
df.tail()
# Out:
#                                  Total population  1800  1810  1820  1830  \
# 270                             Northern Marianas   NaN   NaN   NaN   NaN
# 271  South Georgia and the South Sandwich Islands   NaN   NaN   NaN   NaN
# 272                     US Minor Outlying Islands   NaN   NaN   NaN   NaN
# 273                                Virgin Islands   NaN   NaN   NaN   NaN
# 274                                     West Bank   NaN   NaN   NaN   NaN
#
#      1840  1850  1860  1870  1880  ...  2006  2007  2008  2009  2010  2011  \
# 270   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 271   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 272   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 273   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 274   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2012  2013  2014  2015
# 270   NaN   NaN   NaN   NaN
# 271   NaN   NaN   NaN   NaN
# 272   NaN   NaN   NaN   NaN
# 273   NaN   NaN   NaN   NaN
# 274   NaN   NaN   NaN   NaN
#
# [5 rows x 82 columns]

# %% [markdown]
# [UP](#toc)
# <a id='setindex'/>

# %% [markdown]
# #### Change index to column ```Total population``` and drop the column

# %% [markdown]
# short solution

# %%
df.set_index('Total population', inplace=True)

# %% [markdown]
# longer solution

# %%
#df.index = df['Total population']

# %%
#df.index

# %%
#df.columns

# %%
#df.drop('Total population', axis=1, inplace=True)
#df.columns

# %%
df
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1830       1840       1850  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3448982.0  3625022.0  3810047.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        457234.0   478227.0   506889.0
# Algeria                                       2880355.0  3082721.0  3299305.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1860       1870       1880  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3973968.0  4169690.0  4419695.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        552800.0   610036.0   672544.0
# Algeria                                       3536468.0  3811028.0  4143163.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1890  ...        2006  \
# Total population                                         ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   4710171.0  ...  25183615.0
# Akrotiri and Dhekelia                               NaN  ...     15700.0
# Albania                                        741688.0  ...   3050741.0
# Algeria                                       4525691.0  ...  33749328.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                     2007        2008  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2009        2010  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   27207291.0  27962207.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2929886.0   2901883.0
# Algeria                                       35401790.0  36036159.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2011        2012  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   28809167.0  29726803.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2886010.0   2880667.0
# Algeria                                       36717132.0  37439427.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2013        2014  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   30682500.0  31627506.0
# Akrotiri and Dhekelia                                NaN         NaN
# Albania                                        2883281.0   2889676.0
# Algeria                                       38186135.0  38934334.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2015
# Total population
# Abkhazia                                             NaN
# Afghanistan                                   32526562.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2896679.0
# Algeria                                       39666519.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 81 columns]

# %% [markdown]
# [UP](#toc)
# <a id='loc'/>

# %% [markdown]
# #### Use ```loc``` and ```iloc``` to access entries in DataFrame

# %%
df.loc["Argentina":'Nigeria']
# Out:
#                         1800        1810        1820        1830        1840  \
# Total population
# Argentina           534000.0    534000.0    570719.0    686703.0    873747.0
# Armenia             413326.0    413326.0    423527.0    453507.0    496835.0
# Aruba                19286.0     19286.0     19555.0     20332.0     21423.0
# Australia           351014.0    342440.0    334002.0    348143.0    434095.0
# Austria            3205587.0   3286650.0   3391206.0   3538286.0   3728381.0
# ...                      ...         ...         ...         ...         ...
# New Zealand         100000.0    100000.0    100000.0     91723.0     82479.0
# Ngorno-Karabakh          NaN         NaN         NaN         NaN         NaN
# Nicaragua           219387.0    219387.0    229075.0    258484.0    303135.0
# Niger              1244861.0   1244861.0   1262280.0   1312557.0   1383237.0
# Nigeria           12100855.0  12100855.0  12238319.0  12633330.0  13184823.0
#
#                         1850        1860        1870        1880        1890  \
\
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   5351413.0  5813814.0  6394908.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        901122.0   963956.0  1015991.0
# Algeria                                       5404045.0  6063800.0  6876190.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
#                                                    1940  ...        2000  \
# Total population                                         ...
# Abkhazia                                            NaN  ...         NaN
# Afghanistan                                   7034081.0  ...  19701940.0
# Akrotiri and Dhekelia                               NaN  ...     15157.0
# Albania                                       1123210.0  ...   3121965.0
# Algeria                                       7797418.0  ...  31183658.0
# ...                                                 ...  ...         ...
# Northern Marianas                                   NaN  ...         NaN
# South Georgia and the South Sandwich Islands        NaN  ...         NaN
# US Minor Outlying Islands                           NaN  ...         NaN
# Virgin Islands                                      NaN  ...         NaN
# West Bank                                           NaN  ...         NaN
#
#                                                     2001        2002  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   20531160.0  21487079.0
# Akrotiri and Dhekelia                            15264.0     15372.0
# Albania                                        3124093.0   3123112.0
# Algeria                                       31590320.0  31990387.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2003        2004  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   22507368.0  23499850.0
# Akrotiri and Dhekelia                            15481.0     15590.0
# Albania                                        3117045.0   3103758.0
# Algeria                                       32394886.0  32817225.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2005        2006  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   24399948.0  25183615.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3082172.0   3050741.0
# Algeria                                       33267887.0  33749328.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2007        2008  \
# Total population
# Abkhazia                                             NaN         NaN
# Afghanistan                                   25877544.0  26528741.0
# Akrotiri and Dhekelia                            15700.0     15700.0
# Albania                                        3010849.0   2968026.0
# Algeria                                       34261971.0  34811059.0
# ...                                                  ...         ...
# Northern Marianas                                    NaN         NaN
# South Georgia and the South Sandwich Islands         NaN         NaN
# US Minor Outlying Islands                            NaN         NaN
# Virgin Islands                                       NaN         NaN
# West Bank                                            NaN         NaN
#
#                                                     2009
# Total population
# Abkhazia                                             NaN
# Afghanistan                                   27207291.0
# Akrotiri and Dhekelia                                NaN
# Albania                                        2929886.0
# Algeria                                       35401790.0
# ...                                                  ...
# Northern Marianas                                    NaN
# South Georgia and the South Sandwich Islands         NaN
# US Minor Outlying Islands                            NaN
# Virgin Islands                                       NaN
# West Bank                                            NaN
#
# [275 rows x 70 columns]

# %%
df.iloc[0:5]
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# Akrotiri and Dhekelia  ...     15700.0     15700.0     15700.0         NaN
# Albania                ...   3050741.0   3010849.0   2968026.0   2929886.0
# Algeria                ...  33749328.0  34261971.0  34811059.0  35401790.0
#
#                              2010        2011        2012        2013  \
# Total population
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            27962207.0  28809167.0  29726803.0  30682500.0
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                 2901883.0   2886010.0   2880667.0   2883281.0
# Algeria                36036159.0  36717132.0  37439427.0  38186135.0
#
#                              2014        2015
# Total population
# Abkhazia                      NaN         NaN
# Afghanistan            31627506.0  32526562.0
# Akrotiri and Dhekelia         NaN         NaN
# Albania                 2889676.0   2896679.0
# Algeria                38934334.0  39666519.0
#
# [5 rows x 81 columns]

# %%
df.iloc[0:5,5:10]
# Out:
#                             1850       1860       1870       1880       1890
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0

# %% [markdown]
# [UP](#toc)
# <a id='masking'/>

# %% [markdown]
# #### Use ```masking``` to select data based on condition

# %%
df.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
#                        ...        2006        2007        2008        2009  \
# Total population       ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# Akrotiri and Dhekelia  ...     15700.0     15700.0     15700.0         NaN
# Albania                ...   3050741.0   3010849.0   2968026.0   2929886.0
# Algeria                ...  33749328.0  34261971.0  34811059.0  35401790.0
#
#                              2010        2011        2012        2013  \
# Total population
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            27962207.0  28809167.0  29726803.0  30682500.0
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                 2901883.0   2886010.0   2880667.0   2883281.0
# Algeria                36036159.0  36717132.0  37439427.0  38186135.0
#
#                              2014        2015
# Total population
# Abkhazia                      NaN         NaN
# Afghanistan            31627506.0  32526562.0
# Akrotiri and Dhekelia         NaN         NaN
# Albania                 2889676.0   2896679.0
# Algeria                38934334.0  39666519.0
#
# [5 rows x 81 columns]

# %%
df[df['1800'] >= 10000000]
# Out:
# China             1.326691e+09  1.333807e+09  1.340969e+09  1.348174e+09
# France            6.230953e+07  6.264090e+07  6.296114e+07  6.326840e+07
# Germany           8.066591e+07  8.051968e+07  8.043531e+07  8.042466e+07
# India             1.197070e+09  1.214182e+09  1.230985e+09  1.247446e+09
# Indonesia         2.353608e+08  2.384652e+08  2.416131e+08  2.448083e+08
# Italy             5.931923e+07  5.946720e+07  5.958801e+07  5.967899e+07
# Japan             1.273179e+08  1.273409e+08  1.273198e+08  1.272529e+08
# Nigeria           1.511157e+08  1.552071e+08  1.594247e+08  1.637707e+08
# Pakistan          1.630970e+08  1.665210e+08  1.700439e+08  1.736696e+08
# Russia            1.431232e+08  1.431267e+08  1.431581e+08  1.432115e+08
# Spain             4.581702e+07  4.629519e+07  4.660149e+07  4.670837e+07
# Ukraine           4.602848e+07  4.583071e+07  4.564750e+07  4.547769e+07
# United Kingdom    6.168962e+07  6.222116e+07  6.271668e+07  6.316495e+07
#
#                           2012          2013          2014          2015
# Total population
# Bangladesh        1.552574e+08  1.571574e+08  1.590775e+08  1.609956e+08
# China             1.355387e+09  1.362514e+09  1.369436e+09  1.376049e+09
# France            6.356180e+07  6.384453e+07  6.412125e+07  6.439534e+07
# Germany           8.047795e+07  8.056586e+07  8.064626e+07  8.068854e+07
# India             1.263590e+09  1.279499e+09  1.295292e+09  1.311051e+09
# Indonesia         2.480379e+08  2.512683e+08  2.544548e+08  2.575638e+08
# Italy             5.973772e+07  5.977109e+07  5.978867e+07  5.979768e+07
# Japan             1.271398e+08  1.269850e+08  1.267946e+08  1.265735e+08
# Nigeria           1.682404e+08  1.728165e+08  1.774760e+08  1.822020e+08
# Pakistan          1.773923e+08  1.811926e+08  1.850443e+08  1.889249e+08
# Russia            1.432875e+08  1.433673e+08  1.434294e+08  1.434569e+08
# Spain             4.663708e+07  4.645516e+07  4.625972e+07  4.612170e+07
# Ukraine           4.531995e+07  4.516521e+07  4.500250e+07  4.482376e+07
# United Kingdom    6.357377e+07  6.395565e+07  6.433135e+07  6.471581e+07
#
# [14 rows x 81 columns]

# %% [markdown]
# [UP](#toc)
# <a id='nan'/>

# %% [markdown]
# #### Find NaNs in a column and drop the rows containing an NaN

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# 1800    0
# 1810    0
# 1820    0
# 1830    0
# 1840    0
#        ..
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# Length: 81, dtype: int64

# %%
df.shape
# Out:
# (229, 81)

# %% [markdown]
# [UP](#toc)
# <a id='save'/>

# %% [markdown]
# #### Save DataFrame to ```csv``` or ```xlsx```

# %%
df.to_csv('../../../resources/population_modified.csv')

# %%
df.to_excel('../../../resources/population_modified.xlsx')

# %% [markdown]
# [UP](#toc)
# <a id='plot'/>

# %% [markdown]
# #### Plot histogram

# %%
df['1800'].hist()

# %%
df.columns
# Out:
# Index(['Total population', '1800', '1810', '1820', '1830', '1840', '1850',
#        '1860', '1870', '1880', '1890', '1900', '1910', '1920', '1930', '1940',
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958',
#        '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015'],
#       dtype='object')
